# %%
import pandas as pd

# %%
df = pd.read_csv('uk-data.csv')

# %%
import json

# %%
df
# Out:
#         AREACD                             AREANM     house  salary  \
# 0    W07000052                            Rhondda   62000.0   432.4
# 1    E14000642                            Clacton  150000.0   426.4
# 2    E14000677                          Easington   80000.0   438.7
# 3    W07000071           Merthyr Tydfil and Rhymn   82000.0   434.0
# 4    N06000004                       Belfast West       NaN   390.7
# ..         ...                                ...       ...     ...
# 650  S14000058  West Aberdeenshire and Kincardine       NaN   638.3
# 651          N                   Northern Ireland       NaN   457.2
# 652          W                              Wales       NaN   479.4
# 653          S                           Scotland       NaN   518.2
# 654          E                            England       NaN   523.6
#
#      publicsector  degree   age  nonukborn  health
# 0            38.9    14.0  33.0        2.1    70.6
# ...

# %%
ray = []
for i in df.index:
    ray.append({'name': df['AREANM'][i], 'myValue': df['salary'][i]})

# %%
with open('uk-data-pro.json', 'w') as outfile:
    json.dump(ray, outfile)
